# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

paths = {
    "train" :  "/storage/agrp/dreyet/FullEventReco/HGPflow_ATLAS/data/dijet_JZ1234_May2026/train/train_JZ1234_run4_bw-1.root",
    "val":    "/storage/agrp/dreyet/FullEventReco/HGPflow_ATLAS/data/dijet_JZ1234_May2026/val/val_JZ1234_run4_bw-1.root",
    "test":   "/storage/agrp/dreyet/FullEventReco/HGPflow_ATLAS/data/dijet_JZ1234_May2026/test/test_JZ1234_run4_bw-1.root",
}

# %%
train_file = uproot.open(paths["train"])
val_file = uproot.open(paths["val"])
test_file = uproot.open(paths["test"])

# %%
train_tree = train_file["EventTree"]
train_tree["track_pt"].show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# track_pt             | float[]                  | AsJagged(AsDtype('>f4'))

# %%
# %cd /storage/agrp/dangod/hepattn-nilotpal
# Out:
# /storage/agrp/dangod/hepattn-nilotpal

# %%
from hepattn.experiments.atlas.pflow_data import ATLASDataset

dset = ATLASDataset(
    filepath="/storage/agrp/dreyet/FullEventReco/HGPflow_ATLAS/data/dijet_JZ1234_May2026/val/val_JZ1234_run4_bw-1.root",
    inputs={"hit": ["x", "y", "z", "r", "s", "theta", "phi"]},
    targets={"particle": ["e", "pt", "eta", "sinphi", "cosphi"]},
    scale_dict_path="src/hepattn/experiments/atlas/configs/atlas_var_transform.yaml",
    num_events=1000,
    num_objects=600,
    max_nodes=800,          # max tracks+topoclusters per event — same story
    incidence_cutval=0.01,  # matches configs/base.yaml (default in the class itself is 1e-4)
)

print(len(dset))
event0 = dset.load_event(0)
# Out:
# Seed set to 42
# Loading ATLAS dataset from /storage/agrp/dreyet/FullEventReco/HGPflow_ATLAS/data/dijet_JZ1234_May2026/val/val_JZ1234_run4_bw-1.root with 1000 samples
# Is inference: False
#     Loaded 1000 events and 26 variables in 0.43 seconds
# 100%|██████████| 20/20 [00:00<00:00, 2895.22it/s]
# Removing 0 events with too many nodes or particles
# 0 events with too many nodes
# 0 events with too many particles
# Removing 0 events with mismatching track_particle_idx
# Loading aux var particle_track_idx
# Loading aux var track_particle_idx
# Loading aux var topo2particle_topo_idx
# Loading aux var topo2particle_particle_idx
# Loading aux var topo2particle_energy
# Loading aux var eventNumber
# Number of events after filtering: 1000
# 1000
